# %%
import pandas as pd

BASE = "dados_satisfacao.csv"

dados = pd.read_csv(BASE)

dados
# Out:
#    cliente_id  satisfacao_geral_01-2024  satisfacao_geral_02-2024  \
# 0           1                         4                         3
# 1           2                         5                         2
# 2           3                         3                         1
# 3           4                         4                         4
# 4           5                         4                         4
# 5           6                         5                         2
# 6           7                         3                         4
# 7           8                         4                         4
# 8           9                         5                         3
# 9          10                         3                         4
#
#    satisfacao_geral_03-2024  satisfacao_produto_01-2024  \
# 0                         4                           5
# 1                         4                           4
# 2                         3                           4
# ...
